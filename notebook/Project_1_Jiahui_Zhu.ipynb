# %%
# !pip install anndata
# !pip install 'scanpy[leiden]'
# !pip install louvain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 50.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 56.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 6.8 MB/s eta 0:00:00
# ...
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8023 sha256=31b22bed68d4f379a15e565a312332dc480a0db93a2a0242a4ccabe61a36834d
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built session-info
# ...

# %%
pip install torch --upgrade

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import scanpy as sc
extract_dir = "/content/drive/MyDrive/STAT5243 Jiahui Zhu/Frogtail_files/"
adata = sc.read_h5ad(extract_dir+'cleaned_processed_frogtail.h5ad')
# Out:
# /usr/local/lib/python3.10/dist-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 13199 × 31535
#     obs: 'barcode_cells', 'cell', 'sample', 'DevelopmentalStage', 'DaysPostAmputation', 'cluster', 'X', 'Y', 'CellCyclePhase', 'Sample', 'Lane', 'Condition', 'batch'

# %%
adata.obs
# Out:
#               barcode_cells                  cell   sample DevelopmentalStage  \
# 0        AAACCTGAGCTAGTTC.1    AAACCTGAGCTAGTTC.1   SIGAB5               st40
# 1        AAACCTGGTGGGTCAA.1    AAACCTGGTGGGTCAA.1   SIGAB5               st40
# 2        AAACCTGGTTTGTTGG.1    AAACCTGGTTTGTTGG.1   SIGAB5               st40
# 3        AAACGGGGTCGGCATC.1    AAACGGGGTCGGCATC.1   SIGAB5               st40
# 4        AAACGGGTCCTACAGA.1    AAACGGGTCCTACAGA.1   SIGAB5               st40
# ...                     ...                   ...      ...                ...
# 13194    TTCTTAGAGTACCGGA.1    TTCTTAGAGTACCGGA.1  SIGAB10               st40
# 13195    TTGACTTAGAGTAAGG.1    TTGACTTAGAGTAAGG.1  SIGAB10               st40
# 13196    TTGCGTCTCAAGAAGT.1    TTGCGTCTCAAGAAGT.1  SIGAB10               st40
# 13197    TTGTAGGCAGTACACT.1    TTGTAGGCAGTACACT.1  SIGAB10               st40
# 13198  TTTGCGCAGCGTGAAC.1.1  TTTGCGCAGCGTGAAC.1.1  SIGAB10               st40
#
# ...

# %% [markdown]
# # Data Processing

# %% [markdown]
# Selecting timepoint 0 (Day of amputation)

# %%
adata= adata[adata.obs['DaysPostAmputation'] == 0] # Subset on the time point 0
adata.layers['counts'] = adata.X.copy() # Copy the raw counts in a different layer
# Out:
# <ipython-input-7-11c40912d585>:2: ImplicitModificationWarning: Setting element `.layers['counts']` of view, initializing view as actual.
#   adata.layers['counts'] = adata.X.copy() # Copy the raw counts in a different layer

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 5302 × 31535
#     obs: 'barcode_cells', 'cell', 'sample', 'DevelopmentalStage', 'DaysPostAmputation', 'cluster', 'X', 'Y', 'CellCyclePhase', 'Sample', 'Lane', 'Condition', 'batch'
#     layers: 'counts'

# %% [markdown]
# Normalize data

# %%
sc.pp.normalize_total(adata)
# Logarithmize the data
sc.pp.log1p(adata)

# %% [markdown]
# I choose HVGs as in the original paper:
#
# "Highly variable genes (Fano factor > 65th percentile, HVGs) were selected for clustering and visualization,
# with both lowly (mean expression < 5th percentile) and highly expressed (mean expression > 80th percentile)
# 3
# genes removed" -- From supplmentary material

# %%
sc.pp.filter_genes(adata, min_cells=3)
sc.pp.filter_cells(adata, min_genes=200)

# %%
import numpy as np
import scanpy as sc
from scipy.sparse import issparse

if issparse(adata.X):
    data = adata.X.toarray()
else:
    data = adata.X

adata.var['mean_expression'] = np.mean(data, axis=0)
adata.var['variance'] = np.var(data, axis=0)

# Calculate the Fano factor (variance / mean)
adata.var['fano_factor'] = adata.var['variance'] / adata.var['mean_expression']

# Step 1: Select genes with Fano factor > 65th percentile
fano_threshold = np.percentile(adata.var['fano_factor'], 65)
highly_variable_genes = adata.var['fano_factor'] > fano_threshold

# Step 2: Remove lowly expressed genes (mean expression < 5th percentile)
lowly_expressed_threshold = np.percentile(adata.var['mean_expression'], 5)
not_lowly_expressed = adata.var['mean_expression'] >= lowly_expressed_threshold

# Step 3: Remove highly expressed genes (mean expression > 80th percentile)
highly_expressed_threshold = np.percentile(adata.var['mean_expression'], 80)
not_highly_expressed = adata.var['mean_expression'] <= highly_expressed_threshold

# Combine all filters to get the final set of HVGs
selected_genes = highly_variable_genes & not_lowly_expressed & not_highly_expressed

hvg_adata = adata[:, selected_genes]

# %%
hvg_adata
# Out:
# View of AnnData object with n_obs × n_vars = 5302 × 6905
#     obs: 'barcode_cells', 'cell', 'sample', 'DevelopmentalStage', 'DaysPostAmputation', 'cluster', 'X', 'Y', 'CellCyclePhase', 'Sample', 'Lane', 'Condition', 'batch', 'n_genes'
#     var: 'n_cells', 'mean_expression', 'variance', 'fano_factor'
#     uns: 'log1p'
#     layers: 'counts'

# %%
hvg_adata.var
# Out:
#                    n_cells  mean_expression  variance  fano_factor
# Xelaev18000003m.g       66         0.010605  0.010098     0.952181
# bpi.S                  372         0.065808  0.071569     1.087542
# Xelaev18000024m.g       17         0.002747  0.002763     1.005639
# wnt7c.L                 92         0.014934  0.014102     0.944285
# prickle3.like.L         97         0.015400  0.014935     0.969785
# ...                    ...              ...       ...          ...
# loc100498441.S          39         0.006347  0.006739     1.061711
# loc101734287.S          24         0.003971  0.004584     1.154280
# Xelaev18047963m.g       28         0.003785  0.003475     0.918101
# Xelaev18047968m.g       34         0.004112  0.003800     0.924145
# Xetrov90026938m.S       72         0.011743  0.012307     1.048060
#
# [6905 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# Using pandas plot to create a scatter plot
hvg_adata.var.plot.scatter(x='mean_expression', y='variance', c='fano_factor', colormap='viridis')
# Display the plot
plt.show()

# %% [markdown]
# Scale the data

# %%
sc.pp.scale(hvg_adata, max_value=10)
# Out:
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_scale.py:318: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %% [markdown]
# Principle Component analysis

# %%
sc.tl.pca(hvg_adata)
sc.pp.pca(hvg_adata)

# %%
sc.pl.pca_variance_ratio(hvg_adata, log=True,n_pcs=50)

# %% [markdown]
# # Data Visualization

# %%
sc.pp.neighbors(hvg_adata, n_neighbors=20, n_pcs=40, random_state= 3) # random_state as in originial paper
sc.tl.umap(hvg_adata, min_dist = 0.5, random_state= 3) # min_dist and random_state as in original paper
sc.pl.umap(
    hvg_adata,
    color = ['cluster'], # clusters in paper,
    save='umap_plot.png'
)
# Out:
# WARNING: saving figure to file figures/umapumap_plot.png

# %%
hvg_adata.obs['cluster'].unique()
# Out:
# ['Differentiating neuron', 'Erythrocyte 1', 'Erythrocyte 3', 'Spinal cord progenitor', 'Erythrocyte 4', ..., 'Syndetome', 'Interneuron 4', 'Alpha ionocyte', 'Beta ionocyte', 'Lymphoid 3']
# Length: 43
# Categories (43, object): ['Alpha ionocyte', 'Anterior notochord', 'Beta ionocyte', 'Dermomyotome', ...,
#                           'Spinal cord progenitor', 'Syndetome', 'Vascular endothelial cell',
#                           'Vulnerable Motor Neuron']

# %%
categories = {
    'Somite and others': ['Skeletal muscle', 'Smooth muscle', 'Sclerotome','Syndetome','Myotome', 'Mesenchyme','Anterior notochord','Posterior notochord','Satellite cell', 'Dermomyotome',
'Vascular endothelial cell','Lymphoid endothelial cells','Differentiating myocyte'],
    'Skin': ['Epidermis', 'ROCs', 'Melanocyte', 'Goblet cell','Beta ionocyte','Alpha ionocyte','Melanocyte precursor'
,'Melanocyte stem cell','Small secretory cell','laminin-rich epidermis'],
    'Neural': ['Motor neuron', 'Spinal cord progenitor', 'Differentiating neuron', 'Dopaminergic neurons','Interneuron 1','Interneuron 2','Interneuron 3','Interneuron 4','Floor plate','Oligodendrocyte','Vulnerable Motor Neuron','Motor neuron (leptin+)'],
    'Immune': ['Lymphoid 1 (Gata2-, Gata3+)','Lymphoid 2 (Cxcr6+)','Lymphoid 3','Lymphoid 4 (Gata2+, Gata3-)','Lymphoid 5 (CD19+)','Myeloid 1','Myeloid 2'],
    'Red blood cells': ['Erythrocyte 1', 'Erythrocyte 2', 'Erythrocyte 3','Erythrocyte 4']
}

# %% [markdown]
# Replicate of Figure 1B

# %%
import matplotlib.pyplot as plt
import scanpy as sc

num_categories = len(categories)
rows = 3
cols = (num_categories + 2) // 3

fig, axes = plt.subplots(rows, cols, figsize=(15, 15))
axes = axes.flatten()

for idx, (category, cluster) in enumerate(categories.items()):
    subset = hvg_adata[hvg_adata.obs['cluster'].isin(cluster), :]
    sc.pl.umap(subset, color='cluster', title=category, ax=axes[idx], show=False)

if num_categories < len(axes):
    for i in range(num_categories, len(axes)):
        fig.delaxes(axes[i])

output_filename = 'Figure_1_three_rows_square.png'
plt.savefig(output_filename, dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Clustering Analysis

# %% [markdown]
# ## Ledien clustering

# %%
sc.pp.neighbors(hvg_adata, n_neighbors=20, n_pcs=40, random_state=3)

# %%
sc.tl.umap(hvg_adata,min_dist = 0.5, random_state=3)

# %%
for res in [0.1, 0.5, 0.6, 1.7]:
    sc.tl.leiden(
        hvg_adata, key_added=f"leiden_res_{res:4.2f}", resolution=res, flavor="igraph", random_state = 8, n_iterations=2
    )

# %%
sc.pl.umap(
    hvg_adata,
    color=["leiden_res_0.10", "leiden_res_0.50","leiden_res_0.60", "leiden_res_1.70"],
    legend_loc="on data",
)

# %% [markdown]
# In the highest resolution, it is over-clustered, while the lowest resolution is likely grouping cells which belong to distinct cell identities. And the clusters with resolution 0.6 best appromiate the clusters in the paper.

# %% [markdown]
# - comparison between the clusters in the paper v.s. leiden clustering

# %%
sc.pl.umap(
    hvg_adata,
    color = ['cluster'], # clusters in paper
)
sc.pl.umap(
    hvg_adata,
    color=["leiden_res_0.60"],
    legend_loc="on data",
)

# %% [markdown]
# ## Louvain clustering

# %%
for res in [0.1, 0.5, 0.6, 1.0]:
    sc.tl.louvain(
        hvg_adata, key_added=f"louvain_res_{res:4.2f}", resolution=res, random_state = 8
    )

# %%
sc.pl.umap(
    hvg_adata,
    color=["louvain_res_0.10","louvain_res_0.50", "louvain_res_0.60", "louvain_res_1.00"],
    legend_loc="on data",
)

# %% [markdown]
# - comparison between the clusters ledien clustering v.s. louvain

# %%
import scanpy as sc
import matplotlib.pyplot as plt

# Create a figure with a specific layout
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

sc.pl.umap(
    hvg_adata,
    color=["leiden_res_0.60"],
    legend_loc="on data",
    ax=axes[0],
    show=False
)

sc.pl.umap(
    hvg_adata,
    color=["louvain_res_0.60"],
    legend_loc="on data",
    ax=axes[1],
    show=False
)
plt.savefig('cluster_result.png')
plt.tight_layout()
plt.show()

# %% [markdown]
# Ledien clustering gives more clusters than louvain clustering in the same resulotion

# %% [markdown]
# ## Performance metric

# %%
from sklearn.metrics import silhouette_score, adjusted_rand_score

# %% [markdown]
# ### 1. Silhouette score

# %%
ground_truth_labels = hvg_adata.obs['cluster']
louvain_labels = hvg_adata.obs['louvain_res_0.60']
leiden_labels = hvg_adata.obs['leiden_res_0.60']
umap_coords = hvg_adata.obsm['X_umap']

paper_silhouette = silhouette_score(umap_coords, ground_truth_labels)
louvain_silhouette = silhouette_score(umap_coords, louvain_labels)
leiden_silhouette = silhouette_score(umap_coords, leiden_labels)

print(f"Silhouette Score of clustering in paper: {paper_silhouette:.4f}")
print(f"Louvain Silhouette Score: {louvain_silhouette:.4f}")
print(f"Leiden Silhouette Score: {leiden_silhouette:.4f}")
# Out:
# Silhouette Score of clustering in paper: 0.2060
# Louvain Silhouette Score: 0.4520
# Leiden Silhouette Score: 0.4485

# %% [markdown]
# ### 2. RAND-Index

# %%
from scipy.special import comb
import numpy as np
def rand_index(labels_true, labels_pred):
    tp_plus_fp = comb(np.bincount(labels_pred), 2).sum()
    tp_plus_fn = comb(np.bincount(labels_true), 2).sum()

    A = np.c_[(labels_true, labels_pred)]
    contingency_table = np.array([np.bincount(A[A[:, 0] == i, 1], minlength=len(np.unique(labels_pred)))
                                  for i in np.unique(labels_true)])

    tp = comb(contingency_table, 2).sum()
    fp = tp_plus_fp - tp
    fn = tp_plus_fn - tp
    tn = comb(len(labels_true), 2) - tp - fp - fn

    return (tp + tn) / (tp + fp + fn + tn)

ground_truth_labels = hvg_adata.obs['cluster'].astype('category').cat.codes

louvain_labels = hvg_adata.obs['louvain_res_0.50'].astype('category').cat.codes
leiden_labels = hvg_adata.obs['leiden_res_0.50'].astype('category').cat.codes

louvain_ri = rand_index(ground_truth_labels, louvain_labels)
leiden_ri = rand_index(ground_truth_labels, leiden_labels)

print(f"Louvain Rand Index (RI): {louvain_ri:.4f}")
print(f"Leiden Rand Index (RI): {leiden_ri:.4f}")
# Out:
# Louvain Rand Index (RI): 0.8917
# Leiden Rand Index (RI): 0.9255

# %%
louvain_ari = adjusted_rand_score(ground_truth_labels, louvain_labels)
leiden_ari = adjusted_rand_score(ground_truth_labels, leiden_labels)

print(f"Louvain Adjusted Rand Index (ARI): {louvain_ari:.4f}")
print(f"Leiden Adjusted Rand Index (ARI): {leiden_ari:.4f}")
# Out:
# Louvain Adjusted Rand Index (ARI): 0.5950
# Leiden Adjusted Rand Index (ARI): 0.6561

# %% [markdown]
# ### 3. Davies-Bouldin Index

# %% [markdown]
# The Davies-Bouldin Index is computed as follows:
#
# $$
# \text{DBI} = \frac{1}{N} \sum_{i=1}^{N} \max_{j \neq i} \frac{d_i + d_j}{D_{ij}}
# $$
#
# Where:
#
# - \( N \) is the number of clusters.
# - \( d_i \) and \( d_j \) are the intra-cluster distances for clusters \( i \) and \( j \), which measure how compact the clusters are.
# - \( D_{ij} \) is the inter-cluster distance between clusters \( i \) and \( j \), measuring how far apart the clusters are.
# - The \( \max \) operation selects the cluster \( j \) that is closest to cluster \( i \) when considering the ratio of intra-cluster to inter-cluster distances.
#
#  It evaluates how well clusters are separated and how compact they are. A lower DBI value indicates better clustering quality.

# %%
from sklearn.metrics import davies_bouldin_score
paper_dbi = davies_bouldin_score(umap_coords, ground_truth_labels)
ledien_dbi = davies_bouldin_score(umap_coords, leiden_labels)
louvain_dbi = davies_bouldin_score(umap_coords, louvain_labels)

print(f"Davies-Bouldin Index (Paper Clustering): {paper_dbi:.4f}")
print(f"Davies-Bouldin Index (Louvain Clustering): {louvain_dbi:.4f}")
print(f"Davies-Bouldin Index (Ledien Clustering): {ledien_dbi:.4f}")
# Out:
# Davies-Bouldin Index (Paper Clustering): 2.9943
# Davies-Bouldin Index (Louvain Clustering): 0.5947
# Davies-Bouldin Index (Ledien Clustering): 0.7070

# %% [markdown]
# Since Louvain and Leiden each performed better in two of the four metrics,
# it is difficult to conclusively favor one over the other. As a result, both clustering
# methods will be utilized for marker identification in the subsequent analysis

# %% [markdown]
# # Marker Identification

# %% [markdown]
# ## 1. Logistic Regression

# %% [markdown]
# leiden

# %%
sc.tl.rank_genes_groups(hvg_adata, groupby="leiden_res_0.60", method="logreg", max_iter = 1000)

# %%
sc.settings.verbosity = 2  # reduce the verbosity

# %%
roc_markers_logist_ledien = hvg_adata.uns['rank_genes_groups']['names']['10'][:50]

# %% [markdown]
# louvain

# %%
sc.tl.rank_genes_groups(hvg_adata, groupby="louvain_res_0.60", method="logreg", max_iter = 1000)
# Out:
# ranking genes
#     finished (0:00:23)

# %%
roc_markers_logist_louvain = hvg_adata.uns['rank_genes_groups']['names']['10'][:50]

# %% [markdown]
# ## 2. T-test

# %%
sc.tl.rank_genes_groups(hvg_adata, groupby="leiden_res_0.60", method="t-test")
# Out:
# ranking genes
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# ...

# %%
roc_markers_ttest_leiden = hvg_adata.uns['rank_genes_groups']['names']['10'][:50]

# %%
sc.tl.rank_genes_groups(hvg_adata, groupby="louvain_res_0.60", method="t-test")
# Out:
# ranking genes
#     finished (0:00:04)
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# ...

# %%
roc_markers_ttest_louvain = hvg_adata.uns['rank_genes_groups']['names']['10'][:50]

# %% [markdown]
# ## 3. Wilcoxon

# %%
sc.tl.rank_genes_groups(hvg_adata, groupby="leiden_res_0.60", method="wilcoxon")
# Out:
# ranking genes
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# ...

# %%
sc.pl.rank_genes_groups(hvg_adata, n_genes=25, sharey=False)

# %% [markdown]
# Show top ranked genes per cluster 0,...20 in a dataframe

# %%
import pandas as pd
pd.DataFrame(hvg_adata.uns['rank_genes_groups']['names']).head(5)
# Out:
#               0                  1        2                  3          4  \
# 0        myt1.L             tal1.L   hbg1.S            iqca1.L    ccnb3.S
# 1       map1a.L             ccl4.L   rln3.S         c1orf158.L  ccnb1.2.S
# 2        syt4.S            ramp3.L  actc1.L             msi1.S    cenpf.L
# 3  map1a.like.L             cd34.L   myl1.S  Xelaev18024815m.g    ccnb3.L
# 4        nsg1.S  Xelaev18047861m.g  gsta4.S            duox1.L     plk1.L
#
#                5          6                  7                  8  \
# 0      slc18a3.S      cck.S            cmahp.L              shh.L
# 1       atp1a3.S      cck.L          tmem45b.S     loc101731931.S
# 2         lhx3.L   prdm14.L     loc100492852.S             npr3.S
# 3        cntn1.L     tlx3.L  Xelaev18022549m.g           ferd3l.L
# 4  atp2b2.like.L  adcyap1.L           rab27a.S  Xelaev18046818m.g
#
#                 9  ...         12                 13                 14  \
# ...

# %% [markdown]
# Single cluster (10)

# %%
sc.tl.rank_genes_groups(hvg_adata, "leiden_res_0.60", groups=["10"], method="wilcoxon")
sc.pl.rank_genes_groups(hvg_adata, groups=["10"], n_genes=20)
# Out:
# ranking genes
#     finished (0:00:02)
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(

# %%
dc_cluster_genes = sc.get.rank_genes_groups_df(hvg_adata, group="10").head(10)["names"]
sc.pl.umap(
    hvg_adata,
    color=[*dc_cluster_genes, "leiden_res_0.60"],
    legend_loc="on data",
    frameon=False,
    ncols=3,
    save="_cluster_markers.png"
)
# Out:
# WARNING: saving figure to file figures/umap_cluster_markers.png

# %%
roc_markers_wilcoxon_leiden = hvg_adata.uns['rank_genes_groups']['names']['10'][:50]

# %%
sc.tl.rank_genes_groups(hvg_adata, groupby="louvain_res_0.60", method="wilcoxon")
# Out:
# ranking genes
#     finished (0:00:07)
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# ...

# %%
roc_markers_wilcoxon_louvain = hvg_adata.uns['rank_genes_groups']['names']['10'][:50]

# %%
roc_markers_wilcoxon_leiden
# Out:
# array(['egfl6.L', 'lpar3.L', 'sp9.L', 'fgf7.L', 'vwde.L', 'tinagl1.S',
#        'cpa6.S', 'cpa6.L', 'fgf7.S', 'rspo2.L', 'fgf9.L', 'fgfr4.L',
#        'col27a1.S', 'lef1.S', 'krt.L', 'loc100127750.S', 'loc100488523.L',
#        'fn1.L', 'nid2.S', 'c3.L', 'Xelaev18046800m.g', 'tp73.L',
#        'lamb2.L', 'jag1.L', 'lef1.L', 'fbn2.S', 'dlx2.S', 'wnt5a.S',
#        'prss35.S', 'tp63.L', 'loc100498358.L', 'gpx8.S', 'unc5b.S',
#        'dlx2.L', 'kremen2.L', 'mmp28.L', 'rbp1.L', 'Xelaev18044182m.g',
#        'igfbp2.L', 'fzd10.L', 'nckap5l.L', 'ism2.L', 'ecm1.L',
#        'loc100492954.S', 'sema3f.L', 'lamb1.L', 'xarp.like.S',
#        'Xelaev18034799m.g', 'lamb1.S', 'loc100497848.L'], dtype=object)

# %% [markdown]
# ## Compare identified markers across methods

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/STAT5243 Jiahui Zhu/MarkerList(SuppTable3).xlsx'
excel_data = pd.read_excel(file_path, sheet_name='ROC markers', header=None)
excel_data.columns = ['roc_markers']

# %%
excel_data.head()
# Out:
#     roc_markers
# 0         wnt5a
# 1  loc100488523
# 2  loc100492954
# 3         egfl6
# 4         lpar3

# %%
common_markers_wilcoxon = roc_markers_wilcoxon_leiden[np.isin(roc_markers_wilcoxon_leiden, roc_markers_wilcoxon_louvain)]
unique_to_leiden_wilcoxon = roc_markers_wilcoxon_leiden[~np.isin(roc_markers_wilcoxon_leiden, roc_markers_wilcoxon_louvain)]
unique_to_louvain_wilcoxon = roc_markers_wilcoxon_louvain[~np.isin(roc_markers_wilcoxon_louvain, roc_markers_wilcoxon_leiden)]

len(common_markers_wilcoxon),len(unique_to_leiden_wilcoxon),len(unique_to_louvain_wilcoxon)
# Out:
# (47, 3, 3)

# %%
common_markers_logist = roc_markers_logist_ledien[np.isin(roc_markers_logist_ledien, roc_markers_logist_louvain)]
unique_to_leiden_logist = roc_markers_logist_ledien[~np.isin(roc_markers_logist_ledien, roc_markers_logist_louvain)]
unique_to_louvain_logist = roc_markers_logist_louvain[~np.isin(roc_markers_logist_louvain, roc_markers_logist_ledien)]

len(common_markers_logist),len(unique_to_leiden_logist),len(unique_to_louvain_logist)
# Out:
# (23, 27, 27)

# %%
common_markers_ttest = roc_markers_ttest_leiden[np.isin(roc_markers_ttest_leiden, roc_markers_ttest_louvain)]
unique_to_leiden_ttest = roc_markers_ttest_leiden[~np.isin(roc_markers_ttest_leiden, roc_markers_ttest_louvain)]
unique_to_louvain_ttest = roc_markers_ttest_louvain[~np.isin(roc_markers_ttest_louvain, roc_markers_ttest_leiden)]

len(common_markers_ttest),len(unique_to_leiden_ttest),len(unique_to_louvain_ttest)
# Out:
# (48, 2, 2)

# %% [markdown]
# Any common markers with paper?

# %%
roc_markers_wilcoxon_leiden = np.array([gene.split('.')[0] for gene in roc_markers_wilcoxon_leiden])
roc_markers_wilcoxon_louvain = np.array([gene.split('.')[0] for gene in roc_markers_wilcoxon_louvain])

roc_markers_logist_leiden = np.array([gene.split('.')[0] for gene in roc_markers_logist_ledien])
roc_markers_logist_louvain = np.array([gene.split('.')[0] for gene in roc_markers_logist_louvain])

roc_markers_ttest_leiden = np.array([gene.split('.')[0] for gene in roc_markers_ttest_leiden])
roc_markers_ttest_louvain = np.array([gene.split('.')[0] for gene in roc_markers_ttest_louvain])

# %%
# Wilcoxon
common_markers_wilcoxon_leiden = roc_markers_wilcoxon_leiden[np.isin(roc_markers_wilcoxon_leiden, excel_data)]
common_markers_wilcoxon_louvain = roc_markers_wilcoxon_louvain[np.isin(roc_markers_wilcoxon_louvain, excel_data)]

# Logistic
common_markers_logist_leiden = roc_markers_logist_leiden[np.isin(roc_markers_logist_leiden, excel_data)]
common_markers_logist_louvain = roc_markers_logist_louvain[np.isin(roc_markers_logist_louvain, excel_data)]

# T-test
common_markers_ttest_leiden = roc_markers_ttest_leiden[np.isin(roc_markers_ttest_leiden, excel_data)]
common_markers_ttest_louvain = roc_markers_ttest_louvain[np.isin(roc_markers_ttest_louvain, excel_data)]

# %%
len(common_markers_wilcoxon_leiden),len(common_markers_wilcoxon_louvain), \
len(common_markers_logist_leiden),len(common_markers_logist_louvain), \
len(common_markers_ttest_leiden),len(common_markers_ttest_louvain)
# Out:
# (36, 36, 29, 34, 37, 36)

# %% [markdown]
# Are the markers identified by Leiden and Louvain clustering methods the same when using the same identification method?

# %%
common_markers_wilcoxon = common_markers_wilcoxon_leiden[np.isin(common_markers_wilcoxon_leiden, common_markers_wilcoxon_louvain)]
len(common_markers_wilcoxon)
# Out:
# 35

# %%
common_markers_logist = common_markers_logist_leiden[np.isin(common_markers_logist_leiden, common_markers_logist_louvain)]
len(common_markers_logist)
# Out:
# 21

# %%
common_markers_ttest = common_markers_ttest_leiden[np.isin(common_markers_ttest_leiden, common_markers_ttest_louvain)]
len(common_markers_ttest)
# Out:
# 36

# %% [markdown]
# Any common markers across methods? (leiden as example)

# %%
common_markers_1 = roc_markers_wilcoxon_leiden[np.isin(roc_markers_wilcoxon_leiden, roc_markers_logist_leiden)]
common_markers_2 = roc_markers_logist_leiden[np.isin(roc_markers_logist_leiden, roc_markers_ttest_leiden)]
common_markers_3 = roc_markers_ttest_leiden[np.isin(roc_markers_ttest_leiden, roc_markers_wilcoxon_leiden)]

len(common_markers_1), len(common_markers_2), len(common_markers_3)
# Out:
# (33, 33, 49)

# %% [markdown]
# Markers identified by wilcoxon and t-test are most similar
